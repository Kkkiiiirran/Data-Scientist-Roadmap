# %%
import pandas as pd

# %%
var = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
var
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
var["C"] = var["a"] + var["b"]
var
# Out:
#    a  b  C
# 0  1  4  5
# 1  2  5  7
# 2  3  6  9

# %%
var["D"] = var["C"] - var["b"]
var
# Out:
#    a  b  C  D
# 0  1  4  5  1
# 1  2  5  7  2
# 2  3  6  9  3

# %%
var["E"] = var["a"] * var["b"]
var
# Out:
#    a  b  C  D   E
# 0  1  4  5  1   4
# 1  2  5  7  2  10
# 2  3  6  9  3  18

# %%
var["F"] = var["E"] / var["a"]
var
# Out:
#    a  b  C  D   E    F
# 0  1  4  5  1   4  4.0
# 1  2  5  7  2  10  5.0
# 2  3  6  9  3  18  6.0

# %% [markdown]
# Logical Operators

# %%
var1 = pd.DataFrame({'a': [14, 22, 131], 'b': [45, 52, 61]})
var1
# Out:
#      a   b
# 0   14  45
# 1   22  52
# 2  131  61

# %%
var1["Python"] = var1["a"] <= 22
var1["Python_1"] = var1["b"] >= 46
var1
# Out:
#      a   b  Python  Python_1
# 0   14  45    True     False
# 1   22  52    True      True
# 2  131  61   False      True

# %% [markdown]
# INSERT

# %%
var = pd.DataFrame({'a': [1, 2, 3, 4, 5], 'b': [4, 5, 6, 7, 8]})
var
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6
# 3  4  7
# 4  5  8

# %%
var.insert(1, "j", [11, 22, 33, 54,75])
var
# Out:
#    a   j  i  h  typhoon  python  b
# 0  1  11  1  1        1       1  4
# 1  2  22  2  2        2       2  5
# 2  3  33  3  3        3       3  6
# 3  4  54  4  4        4       4  7
# 4  5  75  5  5        5       5  8

# %%
var["new"] = var["a"][:3]
var
# Out:
#    a   j  i  h  typhoon  python  b  new
# 0  1  11  1  1        1       1  4  1.0
# 1  2  22  2  2        2       2  5  2.0
# 2  3  33  3  3        3       3  6  3.0
# 3  4  54  4  4        4       4  7  NaN
# 4  5  75  5  5        5       5  8  NaN

# %% [markdown]
# Delete

# %%
var.pop("j")
var
# Out:
#    a  i  h  typhoon  python  b  new
# 0  1  1  1        1       1  4  1.0
# 1  2  2  2        2       2  5  2.0
# 2  3  3  3        3       3  6  3.0
# 3  4  4  4        4       4  7  NaN
# 4  5  5  5        5       5  8  NaN

# %%
var.pop("i")
var
# Out:
#    a  h  typhoon  python  b  new
# 0  1  1        1       1  4  1.0
# 1  2  2        2       2  5  2.0
# 2  3  3        3       3  6  3.0
# 3  4  4        4       4  7  NaN
# 4  5  5        5       5  8  NaN

# %%
var.pop("h")
var.pop("typhoon")
var.pop("python")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'h'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 var.pop("h")
#       2 var.pop("typhoon")
#       3 var.pop("python")
#
# ...

# %%
var
# Out:
#    a  b  new
# 0  1  4  1.0
# 1  2  5  2.0
# 2  3  6  3.0
# 3  4  7  NaN
# 4  5  8  NaN

# %%
del var["new"]
var
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6
# 3  4  7
# 4  5  8

# %%
del (var["a"], var["b"])

# %%
var.insert(0, "j", [11, 22, 33, 54,75])

# %%
var.insert(1, "i", [11, 22, 33, 54,75])

# %%
var
# Out:
#     j   i
# 0  11  11
# 1  22  22
# 2  33  33
# 3  54  54
# 4  75  75
